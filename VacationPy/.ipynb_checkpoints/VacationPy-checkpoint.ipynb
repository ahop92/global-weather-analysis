# %%
# Import all of the relevant dependencies to evaluate weather data and generate 
# graph outputs

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import scipy.stats as sts
import gmaps

import json
import requests
from config import apikey as g_key

# %%
#Importing data from WeatherPy

weather_filepath = "../WeatherPy/output_data/cities.csv"
weather_df = pd.read_csv(weather_filepath)
weather_df
weather_df.loc[weather_df["Country"] == "BR", :]
# Out:
#                          City  Latitude  Longitude  Maxium Temperature (F)  \
# 10                 Vila Velha  -20.3297   -40.2925                   87.01
# 21                    Itaguaí  -22.8522   -43.7753                   82.40
# 94                   Cidreira  -30.1811   -50.2056                   70.75
# 95                  Guarapari  -20.6667   -40.4975                   87.01
# 123                    Touros   -5.1989   -35.4608                   86.00
# 162                   Camocim   -2.9022   -40.8411                   84.96
# 165                    Castro  -24.7911   -50.0119                   65.95
# 186                     Borba   -4.3878   -59.5939                   88.99
# 190                    Maricá  -22.9194   -42.8186                   82.40
# 193               Morada Nova   -5.1067   -38.3725                   87.91
# 221           Arraial do Cabo  -22.9661   -42.0278                   84.20
# 238                  Eldorado  -23.7869   -54.2836                   66.92
# 271                    Balsas   -7.5325   -46.0356                   86.05
# 288                   Pitimbu   -7.4706   -34.8086                   86.00
# 299               Mangaratiba  -22.9597   -44.0406                   82.40
# 302                Rio Grande  -32.0350   -52.0986                   71.60
# 304         Euclides da Cunha  -10.5075   -39.0158                   79.59
# 360                  Maragogi   -9.0122   -35.2225                   82.90
# 429                    Bonfim    3.0833   -59.9500                   84.56
# 461                     Prado  -17.3411   -39.2208                   81.28
# 483                     Jutaí   -5.1833   -68.9000                   75.42
# 484                    Maceió   -9.6658   -35.7353                   86.00
# 514  São José da Coroa Grande   -8.8978   -35.1478                   82.13
# 546                  Imbituba  -28.2400   -48.6703                   75.20
# 561                    Olinda   -8.0089   -34.8553                   80.60
# 587                    Manaus   -3.1019   -60.0250                   84.20
#
#      Humidity (%)  Cloudiness (%)  Wind Speed (mph) Country        Date  \
# 10             66              20             13.80      BR  1619371513
# 21             61              20              6.91      BR  1619371788
# 94             72              87             15.61      BR  1619371816
# 95             66              20             13.80      BR  1619371816
# 123            66              40             14.97      BR  1619371826
# 162            68              62             10.69      BR  1619371839
# 165            71             100              5.06      BR  1619371564
# 186            60              75              4.63      BR  1619371845
# 190            78              20             12.66      BR  1619371846
# 193            56              98              3.31      BR  1619371847
# 221            65               0              9.22      BR  1619371853
# 238            86              94              5.26      BR  1619371857
# 271            61              91              3.67      BR  1619371866
# 288            66              20             12.66      BR  1619371787
# 299            61              20              6.91      BR  1619371875
# 302            43              75             17.27      BR  1619371875
# 304            67              68              6.53      BR  1619371876
# 360            70              20             10.40      BR  1619371635
# 429            62             100              7.58      BR  1619371912
# 461            69               9             10.27      BR  1619371924
# 483            92              86              3.56      BR  1619371932
# 484            58              40              8.05      BR  1619371765
# 514            72              31              9.84      BR  1619371943
# 546            78              75             11.50      BR  1619371846
# 561            78              40             11.50      BR  1619371960
# 587            79              40              3.44      BR  1619371833
#
#               Hemisphere
# 10   Southern Hemisphere
# 21   Southern Hemisphere
# 94   Southern Hemisphere
# 95   Southern Hemisphere
# 123  Southern Hemisphere
# 162  Southern Hemisphere
# 165  Southern Hemisphere
# 186  Southern Hemisphere
# 190  Southern Hemisphere
# 193  Southern Hemisphere
# 221  Southern Hemisphere
# 238  Southern Hemisphere
# 271  Southern Hemisphere
# 288  Southern Hemisphere
# 299  Southern Hemisphere
# 302  Southern Hemisphere
# 304  Southern Hemisphere
# 360  Southern Hemisphere
# 429  Northern Hemisphere
# 461  Southern Hemisphere
# 483  Southern Hemisphere
# 484  Southern Hemisphere
# 514  Southern Hemisphere
# 546  Southern Hemisphere
# 561  Southern Hemisphere
# 587  Southern Hemisphere

# %%
#Configure gmaps 

gmaps.configure(api_key=g_key)

locations = weather_df[["Latitude", "Longitude"]].astype(float)


fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=weather_df["Humidity (%)"], 
                              dissipating=False, 
                              max_intensity=weather_df["Humidity (%)"].max().astype(float), 
                              point_radius = 2)
    
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
